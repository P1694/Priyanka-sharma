# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
from sklearn.datasets import load_diabetes
Dia=load_diabetes()
Dia
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990842, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06832974, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286377, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04687948,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452837, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00421986,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
Dia_data=pd.DataFrame(data=Dia.data, columns=Dia.feature_names)
Dia_target=pd.DataFrame(data=Dia.target, columns=["Diabities"])

# %%
Dia_data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6'], dtype='object')

# %%
Dia_data["s6"]
# Out:
# 0     -0.017646
# 1     -0.092204
# 2     -0.025930
# 3     -0.009362
# 4     -0.046641
# 5     -0.096346
# 6     -0.038357
# 7      0.003064
# 8      0.011349
# 9     -0.013504
# 10    -0.034215
# 11    -0.059067
# 12    -0.042499
# 13    -0.013504
# 14    -0.075636
# 15    -0.042499
# 16     0.027917
# 17    -0.001078
# 18    -0.017646
# 19    -0.054925
# 20     0.015491
# 21    -0.017646
# 22    -0.013504
# 23     0.135612
# 24    -0.054925
# 25    -0.034215
# 26    -0.005220
# 27     0.040343
# 28    -0.054925
# 29     0.052770
# 30    -0.009362
# 31    -0.042499
# 32     0.027917
# 33     0.003064
# 34    -0.067351
# 35     0.019633
# 36    -0.025930
# 37    -0.005220
# 38     0.023775
# 39     0.003064
# 40     0.094191
# 41    -0.009362
# 42    -0.034215
# 43     0.073480
# 44    -0.017646
# 45    -0.050783
# 46    -0.088062
# 47    -0.083920
# 48    -0.021788
# 49    -0.013504
# 50     0.007207
# 51    -0.021788
# 52    -0.013504
# 53     0.048628
# 54     0.007207
# ...

# %%
Dia_data.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.634285e-16  1.308343e-16 -8.045349e-16  1.281655e-16 -8.835316e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.327024e-16 -4.574646e-16  3.777301e-16 -3.830854e-16 -3.412882e-16
# ...

# %%
print(Dia_data.shape)
print(Dia_target.shape)
# Out:
# (442, 10)
# (442, 1)

# %%
for i in Dia_data:
    if Dia_data[i].dtypes !="object":
        .scatterplot(x=Dia_data[i], y=Dia_data)

# %%
for i in Dia_data:
    if Dia_data[i].dtypes!='object':
        plt.title(i)
        plt.hist(Dia_data[i])
        plt.show()
        plt.boxplot(Dia_data[i])
        plt.show()
        plt.scatter(Dia_data[i],Dia_target('Dia_target')
        plt.xlabel(i)
        plt.ylabel('Dia_target')
        plt.show()
    else:
        sns.countplot(Dia_data[i])
        plt.show()
# Out:
#   File "<ipython-input-13-d58de0c0ec3a>", line 9
#     plt.xlabel(i)
#       ^
# SyntaxError: invalid syntax

# %%
from sklearn.preprocessing import LabelEncoder
L=LabelEncoder()
for i in Dia_data:
    if Dia_data[i].dtypes=='object':
        Dia_data[i]=L.fit_transform(Dia_data[i].astype(str))

# %%
plt.scatter(Dia_target,Dia_data["age","sex"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('age', 'sex')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-5cd86fabcf21> in <module>
# ...

# %%
for i in Dia_data:
    if Dia_data[i].dtypes!='object':
        plt.scatter(Dia_target),Dia_Data([i])
        plt.xlabel("Dia_target")
        plt.ylabel('')
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-d65f1ed40348> in <module>
#       1 for i in Dia_data:
#       2     if Dia_data[i].dtypes!='object':
# ----> 3         plt.scatter(Dia_target),Dia_Data([i])
#       4         plt.xlabel("Dia_target")
#       5         plt.ylabel('')
#
# TypeError: scatter() missing 1 required positional argument: 'y'
